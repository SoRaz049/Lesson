# %% [markdown]
# MATPLOTLIB DETAIL LESSON

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pygwalker as pyg
import seaborn as sns

# %%
x_data = np.random.random(1000) * 100
y_data = np.random.random(1000) * 100

# %%
x_data
# Out:
# array([32.72996871, 84.69443209, 14.27470777, 27.60481666, 34.0082492 ,
#        48.51176447, 15.59575992, 93.65370253, 47.97465078, 51.85796008,
#        26.0034909 , 71.9772462 , 15.64603148, 41.1770608 ,  9.73382994,
#        92.66497289, 64.06539446,  0.73017418, 62.62434741, 11.22948088,
#        17.24166003, 41.1922694 , 42.54251716, 88.15112351, 77.84986679,
#         3.01821895, 24.3419837 , 44.36725052, 87.88522251, 51.19062428,
#        50.83956375, 10.42374488,  7.99751822, 88.64559943, 29.42839296,
#        83.1330238 , 25.72968367, 81.25082914, 80.82148026, 17.03487765,
#        51.03690219, 96.85906726,  9.94766091, 51.71479113, 57.01294672,
#        68.09838722,  0.30401576, 79.92470969, 66.57820137, 11.52647822])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.title("Random")
plt.xlabel("X data")
plt.ylabel("Y data")
plt.scatter(x_data, y_data, color="Red", marker="*", s=150, alpha=0.3)
plt.show()

# %%
years = [2000 + x for x in range(25)]

# Generate a single random integer between 50 and 70
weight = [int(np.random.uniform(50,70)) for _ in range (25)]

# %%
plt.figure(figsize=(12,4))
plt.plot(years, weight, c= "green", lw= 3, linestyle = "--")
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight Chart")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.scatter(years, weight, c= "green", lw= 3, linestyle = "--")
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight Chart")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.bar(years, weight, color = "grey")
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight Chart")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.hist(years)
plt.xlabel("Years")
plt.ylabel("Weight")
plt.title("Weight Chart")
plt.show()

# %%
import seaborn as sns
sns.histplot(years)
plt.title("Weight Chart")
plt.show()
